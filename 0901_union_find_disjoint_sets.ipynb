# %% [markdown]
# <a href="https://colab.research.google.com/github/lmcanavals/algorithmic_complexity2023/blob/main/0901_union_find_disjoint_sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Union Find Disjoint Set

# %%
import graphviz

# %%
class DisjointSet:
    # __private__
    # _protected_
    # public
    def __init__(self, n): # constructor
        self.__id__ = [-1]*n

    def find(self, a): # find with path compression
        if self.__id__[a] < 0:
            return a
        parent = self.find(self.__id__[a])
        self.__id__[a] = parent
        return parent

    def union(self, a, b):
        repA = self.find(a)
        repB = self.find(b)
        if repA == repB:
            return
        if self.__id__[repA] < self.__id__[repB]:
            self.__id__[repA] += self.__id__[repB]
            self.__id__[repB] = repA
        else:
            self.__id__[repB] += self.__id__[repA]
            self.__id__[repA] = repB

    def isSameSet(self, a, b):
        return self.find(a) == self.find(b)

    def getDot(self):
        dot = graphviz.Digraph("UFDS")
        dot.graph_attr['rankdir'] = 'BT'
        for i in range(len(self.__id__)):
            dot.node(str(i))
        for i, e in enumerate(self.__id__):
            if e < 0: continue
            dot.edge(str(i), str(e))
        return dot

# %%
ds = DisjointSet(8)
ds.getDot()

# %%
ds.union(0, 3)
ds.getDot()

# %%
ds.union(3, 5)
print(ds.__id__)
ds.getDot()
# Out:
# [3, -1, -1, -3, -1, 3, -1, -1]

# %%
ds.union(1, 4)
ds.union(2, 4)
ds.getDot()

# %%
ds.union(5, 1)
ds.getDot()

# %%
ds.union(7, 6)
ds.getDot()

# %% [markdown]
# We observe the compression of the path from 4 to 5, making 5 direct child of 4

# %%
ds.union(5, 7)
ds.getDot()

# %% [markdown]
# ## Ejercicios
